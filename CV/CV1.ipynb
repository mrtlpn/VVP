# %% [markdown]
# ---
#
# # Úkoly: Úvod do Pythonu

# %% [markdown]
# 1. Vypište své jméno pomocí `print()`.

# %%
print("Vsevolod Kucheriavyi")
# Out:
# Vsevolod Kucheriavyi

# %% [markdown]
# 2. Vytvořte proměnnou s textem svého jména a vypište ji.

# %%
name = "Vsevolod Kucheriavyi"
print(name)
# Out:
# Vsevolod Kucheriavyi

# %% [markdown]
# 3. Vytvořte proměnnou s číslem `10` a vypište ji.

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# 4. Vytvořte proměnné s čísly `2` a `3`, sečtěte je a vypište výsledek.

# %%
a = 2
b = 3
c = a + b
print(c)
# Out:
# 5

# %% [markdown]
# 5. Vytvořte proměnnou s hodnotou `2.5` a vypište její dvojnásobek.

# %%
d = 2.5
print(d*d)
# Out:
# 6.25
